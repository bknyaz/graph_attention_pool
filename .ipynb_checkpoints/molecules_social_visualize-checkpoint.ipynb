# %%
import matplotlib.pyplot as plt
import argparse
import os
import sys
from os.path import join as pjoin
import numpy as np
import time
import datetime
import platform
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import datasets
from sklearn.metrics import average_precision_score as avg_precision
from collections import OrderedDict
import pickle
from matplotlib import cm
#import graphdata
#from image_superpixels import ImageSP
#import models as my_models
#import utils
#import pascal_loader
import networkx as nx
import cv2
from scipy.spatial.distance import cdist
#from sklearn.manifold import TSNE
import importlib
#import visdom
import matplotlib as mlp
from sklearn.metrics import roc_auc_score, roc_curve
import seaborn as sns
import chebygin as my_models
import importlib
from sklearn.metrics import roc_auc_score, roc_curve
import graphdata

# %%
def read_results(results_dir, epoch=50):
    acc = []
    for f in os.listdir(results_dir):
        with open(pjoin(results_dir, f), 'r') as fp:
            lines = fp.readlines()#[-1]        
        
        try:
            if lines[-1].find('cross validation avg acc') >= 0:
                s = lines[-1]
                pos1 = s.find(':')
                acc.append(float(s[pos1+1:s[pos1:].find('(') + pos1]))
            else:
                s = list(filter(lambda l: l.find('Test set (epoch %d):' % epoch) >= 0, lines))[0]
                pos1 = s.find(':')
                pos2 = pos1 + s[pos1:].find('%')
                pos1 = pos1 + s[pos1:].find('(')
                acc.append(float(s[pos1+1:pos2]))
        except:
            continue
    print(len(acc), np.mean(acc), np.std(acc), np.min(acc), np.max(acc))

# %%
read_results('/export/mlrg/bknyazev/projects/graph_nn/repeats/mcheb_paper/')
# Out:
# 10 76.04583333333333 0.499241559121176 75.27380952380953 77.10714285714286

# %% [markdown]
# # COLLAB

# %%
[1e-4, 1e-3, 2e-3, 5e-3, 1e-2, 3e-2, 5e-2, 1e-1]
# Out:
# [0.0001, 0.001, 0.002, 0.005, 0.01, 0.03, 0.05, 0.1]

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/collab_global_max/')
# Out:
# 10 65.895 3.0055423803366996 57.36 69.07

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/collab_unsup_10fold_fc32/')
# Out:
# 7 64.37285714285714 3.218037175873847 56.71 66.8

# %%
#read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/collab_wsup_5fold_88nodes/')

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/collab_wsup_5fold/')
# Out:
# 7 60.79428571428572 4.018250710882811 54.73 65.87

# %% [markdown]
# # PROTEINS

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/proteins_global_max/')
# Out:
# 10 72.691 1.5268100733228065 68.68 74.06

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/proteins_unsup_10fold/')
# Out:
# 10 76.36200000000001 0.4289009209596077 75.53 77.0

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/proteins_wsup_5fold/')
# Out:
# 10 76.136 0.9321072899618367 74.39 77.98

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/proteins_wsup_10fold/')
# Out:
# 7 76.39285714285714 0.8478664700413668 75.37 77.81

# %% [markdown]
# # DD - 200

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_200nodes_global_max/')
# Out:
# 10 31.453000000000003 3.977773372126672 25.28 37.29

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_200nodes_5fold/')
# Out:
# 10 57.333000000000006 18.045085231164744 21.37 67.74

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_200nodes_10fold/')
# Out:
# 10 46.271 20.370703694276248 21.37 65.22

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_wsup_200nodes_5fold/')
# Out:
# 4 41.165 17.067058182358203 21.37 63.13

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_200nodes_10fold_fc32/')
# Out:
# 9 52.84 14.327860195359872 31.01 70.81

# %%
# read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_wsup_200nodes_10fold/')

# %% [markdown]
# # DD - 300

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_300nodes_global_max/')
# Out:
# 10 73.6 2.0625178787103917 68.88 77.29

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_300nodes_5fold/')
# Out:
# 10 77.361 1.249731571178387 75.22 79.06

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_300nodes_10fold/')
# Out:
# 10 76.87299999999998 1.6824924962685572 72.86 78.76

# %%
read_results('/export/mlrg/bknyazev/projects/graph_attention_pool/results/dd_unsup_300nodes_10fold_fc32/')
# Out:
# 6 77.82666666666667 1.4288651285392777 75.07 79.06

# %%
device = 'cpu'
def load_model(model_path, N_nodes_max, in_features=1, out_features=2, my_models=my_models):
    importlib.reload(my_models)
    import chebygin as my_models

    state = torch.load(model_path, map_location=lambda storage, loc: storage)
    print(state['args'].filter_scale)
    model = my_models.ChebyGIN(in_features=in_features,
                              out_features=out_features,
                              K=state['args'].filter_scale,
                              filters=state['args'].filters,
                              dropout=0.1,
                              n_hidden=state['args'].n_hidden,
                              aggregation=state['args'].aggregation,
                              pool=state['args'].pool,
                              pool_arch=state['args'].pool_arch)
    #     print(state['state_dict'])
    print(model)
    model.train()
    print('model capacity: %d' %
          np.sum([np.prod(p.size()) if p.requires_grad else 0 for p in model.parameters()]))

    model.eval()

    try:
        model.load_state_dict(state['state_dict'])
    except Exception as e:
        print('ERROR!!!')
        print(e)
        raise
    model.eval()
    model.to(device)
    print(model)
    return model

# %%
def get_graph(data_test, index, draw=True):
    A = data_test.adj_list[index]
    #print(data_test.features_onehot[index].shape, A.shape)
    G = nx.from_numpy_array(A)
    pos = nx.spring_layout(G)
    if draw:
        nx.draw(G, pos, node_size=200, node_color=np.ones(3), edgecolors=np.zeros(3))
        plt.show()
        print('label', data_test.labels[index])
    return A, G, pos

# %% [markdown]
# # PROTEINS

# %%
# /export/mlrg/bknyazev/projects/XAI/Model/graph_examples/results/proteins/attention_25/wsup_10/K3_f64_64_64_lr0.001_proj4/sup_p0.1_K3_f64_50epochs_shape_split_25nodes_lr0.001_seed468.log
#model = load_model('/mnt/data/bknyazev//checkpoints/checkpoint_PROTEINS_GPU10_764088_fold0_epoch50.pth.tar', 620, 3)

# /export/mlrg/bknyazev/projects/graph_attention_pool/results/proteins_wsup_10fold/proteins_wsup_10fold_cv_seed6149.log
model = load_model('/mnt/data/bknyazev/checkpoints//checkpoint_TU_ws13.cfs.uoguelph.ca_445197_epoch50_seed0006149.pth.tar', 620, 3)
thresh = 0.002
# Out:
# 3
# ChebyGINLayer torch.Size([64, 9]) tensor([0.4909, 0.5030, 0.5087, 0.5213, 0.6198, 0.7971, 0.5189, 0.6657, 0.5467,
#         0.7162], grad_fn=<SliceBackward>)
# ChebyGINLayer torch.Size([64, 192]) tensor([0.5857, 0.5868, 0.5569, 0.6124, 0.6123, 0.5703, 0.5555, 0.5513, 0.5839,
#         0.5749], grad_fn=<SliceBackward>)
# p values [-1.8180276e-01  3.9888140e-02 -6.5564549e-01  1.4403689e+00
#   1.4945427e+00 -1.6161827e-03 -1.4542775e+00 -1.7661189e+00
#   9.2304456e-01 -8.1052762e-01 -3.6928225e-01 -1.0014297e+00
#   5.4176140e-01 -3.0631337e-01  3.8494647e-01  8.9516729e-01
#  -1.4442414e-01 -2.7514589e-01 -2.2782721e-02  1.0548073e+00
#  -9.5661914e-01  2.3108914e-01  4.7699726e-01 -1.1226950e+00
#   1.8035223e-01 -1.8869559e-01  1.3529645e+00 -5.3279035e-02
#   1.5223944e+00  3.6093867e-01  7.6403582e-01  2.2543177e-01
#  -9.3582594e-01  1.1033864e+00  2.1351867e+00  9.8443404e-02
#  -5.5795693e-01  1.8861295e-01 -7.8953177e-01 -9.8441625e-01
#   1.4615088e+00  5.3007025e-01 -6.4137781e-01  1.2658137e+00
#  -8.4135783e-01  1.0714411e+00  7.4508566e-01  7.8566098e-01
#  -1.2541879e+00 -9.0220004e-01  1.0822164e-02 -1.7603434e+00
#  -2.5457862e-01 -9.3901551e-01 -1.7043549e+00  3.6924225e-04
#  -8.2857835e-01  1.0263458e+00 -8.8422686e-01  1.6742532e-01
#   1.3127694e+00  3.1156355e-01  1.2657115e+00 -3.2157341e-01]
# cos_sim 0.005427489522844553
# ChebyGINLayer torch.Size([64, 192]) tensor([0.6116, 0.5542, 0.5526, 0.5734, 0.5288, 0.5761, 0.5656, 0.5795, 0.5741,
#         0.5532], grad_fn=<SliceBackward>)
# ChebyGIN(
#   (layers): Sequential(
#     (0): ChebyGINLayer(in_features=3, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=9, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (1): ChebyGINLayer(in_features=64, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=192, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (2): AttentionPooling(pool_type=['attn', 'sup', 'threshold', '0'], pool_arch=['fc', 'prev'], topk=False, kl_weight=None, proj=Linear(in_features=64, out_features=1, bias=False))
#     (3): ChebyGINLayer(in_features=64, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=192, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (4): GraphReadout(max)
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# model capacity: 25538
# ChebyGIN(
#   (layers): Sequential(
#     (0): ChebyGINLayer(in_features=3, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=9, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (1): ChebyGINLayer(in_features=64, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=192, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (2): AttentionPooling(pool_type=['attn', 'sup', 'threshold', '0'], pool_arch=['fc', 'prev'], topk=False, kl_weight=None, proj=Linear(in_features=64, out_features=1, bias=False))
#     (3): ChebyGINLayer(in_features=64, out_features=64, K=3, n_hidden=0, aggregation=mean)
#     fc=Sequential(
#       (0): Linear(in_features=192, out_features=64, bias=True)
#       (1): ReLU(inplace)
#     )
#     (4): GraphReadout(max)
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
datareader = graphdata.DataReader(data_dir='/mnt/data/bknyazev/data/graph_data/PROTEINS',
                                  rnd_state=np.random.RandomState(6149),
                                  N_nodes=25,
                                  use_cont_node_attr=False,
                                  folds=10)
data_train = graphdata.GraphData(datareader, 0, split='train_val')
data_test = graphdata.GraphData(datareader, 0, split='test')
# Out:
# N nodes avg/std/min/max: 	39.06/45.76/4/620
# N edges avg/std/min/max: 	72.82/84.60/5/1049
# Node degree avg/std/min/max: 	3.73/1.15/0/25
# Node features dim: 		3
# N classes: 			2
# Classes: 			[0 1]
# Class 0: 			663 samples
# Class 1: 			450 samples
# feature 0, count 21151/43471
# feature 1, count 20931/43471
# feature 2, count 1389/43471
# 548/1113 graphs with at least 25 nodes
# generating 10-fold cross-validation splits
# 0 450 50
# 1 450 50
# 2 450 50
# 3 450 50
# 4 450 50
# 5 450 50
# 6 450 50
# 7 450 50
# 8 450 50
# 9 450 50
# TRAIN_VAL: 500/1113
# Class 0: 			209 samples
# Class 1: 			291 samples
# TEST: 613/1113
# Class 0: 			454 samples
# Class 1: 			159 samples

# %%
label == pred
# Out:
# True

# %%
graph_pos, graph_neg = [], []
edgecolors = [0.5, 0.5, 0.5, 0.1] #np.zeros(3)
cmap = 'Purples'
for index in range(len(data_test.adj_list)):
    A, G, pos = get_graph(data_test, index, draw=False)
#     if A.shape[0] < 25:
#         continue
    n = A.shape[0]
    data = [torch.from_numpy(data_test.features_onehot[index]).unsqueeze(0).float().to(device).expand(2, -1, -1),
                torch.from_numpy(A).unsqueeze(0).float().to(device).to(device).expand(2, -1, -1),
                torch.ones(2, n, dtype=torch.uint8).to(device),
                None,
                {'N_nodes': torch.zeros(2, 1).long().to(device) + n,
                 'node_attn': torch.zeros(2, n).float().to(device)}]
    y, output = model(data)
    #print(y, output[1][0].shape)
    alpha = output['alpha'][0][0].data.numpy()
    idx_d = np.where(alpha <= thresh)[0]
    label = data_test.labels[index]
    pred = torch.argmax(y[0]).item()
    if len(idx_d) / float(n) <= 0.3 or label == 1:
        continue
        
    if label != pred:
        continue
    
    if label == pred:
        sfx = 'pos'
        graph_pos.append((A, alpha, label))
    else:
        sfx = 'neg'
        graph_neg.append((A, alpha, label))
    
    print(index, sfx, label, pred)
    
    fig = plt.figure()
#     G = nx.from_numpy_array(graph_pos[0][0])
#     pos = nx.spring_layout(G)
    nx.draw(G, pos, node_size=100, node_color=alpha, #graph_pos[0][1], 
            edgecolors=edgecolors, width=A.sum(1) / 10., cmap=cmap)    
    plt.savefig('images/proteins/wsup/label%d/%s/%d_%dnodes_%d_%d.pdf' % (label, sfx, index, n, label, pred))
    plt.savefig('images/proteins/wsup/label%d/%s/%d_%dnodes_%d_%d.png' % (label, sfx, index, n, label, pred), 
                dpi=300, transparent=True)
    plt.show()
    
    fig = plt.figure()
#     thresh = 0.1
    A = data_test.adj_list[index].copy()
    idx = np.where(alpha > thresh)[0]    
    n = len(idx)
    A = A[:,idx][idx, :]
    G = nx.from_numpy_array(A)
    pos_new = {}
    for j in range(len(idx)):
        pos_new[j] = pos[idx[j]] #+ np.array([0, -0.1])        
    
    idx_d = np.where(alpha <= thresh)[0]
    if len(idx_d) > 0:            
        G_dummy = nx.from_numpy_array(data_test.adj_list[index][:,idx_d][idx_d, :])
        pos_dummy = {}
        for j in range(len(idx_d)):
            pos_dummy[j] = pos[idx_d[j]]        
        nx.draw(G_dummy, pos_dummy, node_color=np.ones((len(pos_dummy), 3)), edge_color='w',
                               node_size=100, width=0, alpha=0)
        
    vmin = alpha.min()
    vmax = alpha.max()
    colors = alpha.copy()[idx]
    nx.draw(G, pos_new, node_color=colors, node_size=100, with_labels=False, width=A.sum(1) / 10.,
                     edgecolors=edgecolors, cmap=cmap, vmin=vmin, vmax=vmax)
    plt.axis('off')
    plt.savefig('images/proteins/wsup/label%d/%s/%d_pooled_%dnodes.pdf' % (label, sfx, index, n))
    plt.savefig('images/proteins/wsup/label%d/%s/%d_pooled_%dnodes.png' % (label, sfx, index, n), 
                dpi=300, transparent=True)
    plt.show()
    #nx.draw(G, pos, node_color=alpha, node_size=(alpha + 0.1) * 1000, edgecolors=np.zeros(3), cmap='Purples')
    #plt.show()
#     break
len(graph_pos), len(graph_neg)
# Out:
# 50 pos 0 0
# 56 pos 0 0
# 59 pos 0 0
# 61 pos 0 0
# 88 pos 0 0
# 96 pos 0 0
# 102 pos 0 0
# 103 pos 0 0
# 163 pos 0 0
# 165 pos 0 0
# 179 pos 0 0
# 201 pos 0 0
# 216 pos 0 0
# 231 pos 0 0
# 243 pos 0 0
# 245 pos 0 0
# 246 pos 0 0
# 249 pos 0 0
# 258 pos 0 0
# 271 pos 0 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-c814ac5ccc49> in <module>()
#      36     nx.draw(G, pos, node_size=100, node_color=alpha, #graph_pos[0][1],
#      37             edgecolors=edgecolors, width=A.sum(1) / 10., cmap=cmap)
# ---> 38     plt.savefig('images/proteins/wsup/label%d/%s/%d_%dnodes_%d_%d.pdf' % (label, sfx, index, n, label, pred))
#      39     plt.savefig('images/proteins/wsup/label%d/%s/%d_%dnodes_%d_%d.png' % (label, sfx, index, n, label, pred),
#      40                 dpi=300, transparent=True)
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2584                 RendererPdf(file, image_dpi, height, width),
#    2585                 bbox_inches_restore=_bbox_inches_restore)
# -> 2586             self.figure.draw(renderer)
#    2587             renderer.finalize()
#    2588             if not isinstance(filename, PdfPages):
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#     909     def draw(self, renderer):
#     910         self.set_sizes(self._sizes, self.figure.dpi)
# --> 911         Collection.draw(self, renderer)
#     912
#     913
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#     335                 self._linewidths, self._linestyles,
#     336                 self._antialiaseds, self._urls,
# --> 337                 self._offset_position)
#     338
#     339         gc.restore()
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offsetTrans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#    1772                 gc, master_transform, all_transforms, path_codes, offsets,
#    1773                 offsetTrans, facecolors, edgecolors, linewidths, linestyles,
# -> 1774                 antialiaseds, urls, offset_position):
#    1775
#    1776             self.check_gc(gc0, rgbFace)
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backend_bases.py in _iter_collection(self, gc, master_transform, all_transforms, path_ids, offsets, offsetTrans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#     548                         gc0.set_linewidth(0)
#     549                     else:
# --> 550                         gc0.set_foreground(fg)
#     551                 else:
#     552                     gc0.set_foreground(fg)
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backend_bases.py in set_foreground(self, fg, isRGBA)
#    1090             self._rgb = fg
#    1091         else:
# -> 1092             self._rgb = colors.to_rgba(fg)
#    1093
#    1094     def set_joinstyle(self, js):
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     219         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     220     # Return a tuple to prevent the cached value from being modified.
# --> 221     c = tuple(c.astype(float))
#     222     if len(c) not in [3, 4]:
#     223         raise ValueError("RGBA sequence should have length 3 or 4")
#
# KeyboardInterrupt:

# %% [markdown]
# # COLLAB

# %%
# /export/mlrg/bknyazev/projects/XAI/Model/graph_examples/results/collab/attention_35/wsup_0.5/K3_f64_64_64_lr0.001_proj6/sup_p0.002_K3_f64_50epochs_shape_split_35nodes_lr0.001_seed127.log
model = load_model('/mnt/data/bknyazev//checkpoints/checkpoint_COLLAB_GPU8_117099_fold0_epoch50.pth.tar', 492, 493, 3)
# Out:
# [array([3]), array([3]), array([3])] concat 35 [32]
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 1479]) tensor([0.5886, 0.5741, 0.5766, 0.5779, 0.5787, 0.5721, 0.5828, 0.5785, 0.5809,
#         0.5803, 0.5832, 0.5708, 0.5861, 0.5792, 0.5771, 0.5768, 0.5707, 0.5780,
#         0.5751, 0.5808, 0.5667, 0.5771, 0.5871, 0.5892, 0.5734, 0.5801, 0.5843,
#         0.5585, 0.5789, 0.5769, 0.5730, 0.5752, 0.5939, 0.5784, 0.5869, 0.5706,
#         0.5862, 0.5793, 0.5725, 0.5784, 0.5806, 0.5880, 0.5841, 0.5861, 0.5824,
#         0.5769, 0.5810, 0.5912, 0.5799, 0.5755, 0.5884, 0.5794, 0.5656, 0.5694,
#         0.5823, 0.5643, 0.5741, 0.5738, 0.5825, 0.5784, 0.5688, 0.5787, 0.5752,
#         0.5829], grad_fn=<NormBackward1>)
# 0 0 ['no', '0.002']
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 192]) tensor([0.5827, 0.5569, 0.5622, 0.5791, 0.5911, 0.5927, 0.5870, 0.5947, 0.5708,
#         0.5683, 0.6016, 0.5696, 0.5883, 0.5586, 0.5903, 0.5824, 0.5677, 0.5797,
#         0.6254, 0.6108, 0.5444, 0.5602, 0.5643, 0.5650, 0.5917, 0.5827, 0.5587,
#         0.6044, 0.5932, 0.5583, 0.5751, 0.5791, 0.5977, 0.5406, 0.5829, 0.5863,
#         0.5903, 0.5946, 0.5413, 0.5967, 0.5919, 0.5728, 0.5685, 0.6434, 0.5607,
#         0.5774, 0.5969, 0.5834, 0.5993, 0.6015, 0.5919, 0.5854, 0.5592, 0.5355,
#         0.5889, 0.5601, 0.5593, 0.5699, 0.5922, 0.5413, 0.5427, 0.5814, 0.5932,
#         0.5609], grad_fn=<NormBackward1>)
# 1 1 ['no', '0.002']
# p= Parameter containing:
# tensor([0.0020], requires_grad=True)
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 192]) tensor([0.5718, 0.5769, 0.5719, 0.5602, 0.5508, 0.5725, 0.5720, 0.5724, 0.5426,
#         0.5923, 0.5744, 0.5849, 0.5746, 0.5827, 0.5690, 0.5452, 0.5772, 0.5409,
#         0.5442, 0.5690, 0.6431, 0.5916, 0.5849, 0.6023, 0.6159, 0.6009, 0.5749,
#         0.5788, 0.5871, 0.6067, 0.5776, 0.5902, 0.5797, 0.5744, 0.5633, 0.5845,
#         0.5889, 0.5802, 0.6153, 0.5703, 0.6173, 0.5210, 0.5901, 0.6133, 0.5977,
#         0.5651, 0.5778, 0.5925, 0.5654, 0.5625, 0.5858, 0.5785, 0.5936, 0.5875,
#         0.5307, 0.5855, 0.6098, 0.5822, 0.5740, 0.5871, 0.6017, 0.5700, 0.5774,
#         0.5667], grad_fn=<NormBackward1>)
# ChebNet(
#   (cheb_layers): ModuleList(
#     (0): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=493, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=1479, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#   )
#   (pooling_layers): ModuleList(
#     (0): IdentityLayer()
#     (1): TopkPooling(in_features=64, in_features2=64, method=proj6, upper_bound=False, select_by_number=False, p=Parameter containing:
#     tensor([0.0020], requires_grad=True), max_iter=None, proj=Sequential(
#       (0): Linear(in_features=64, out_features=32, bias=True)
#       (1): ReLU(inplace)
#       (2): Linear(in_features=32, out_features=1, bias=True)
#     ))
#     (2): GraphPooling(['topk', 'max', 'proj6', 'ada', 'sup', 'const', 'no', '0.002'])
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=3, bias=True)
#   )
# )
# model capacity: 121733
# ChebNet(
#   (cheb_layers): ModuleList(
#     (0): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=493, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=1479, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#   )
#   (pooling_layers): ModuleList(
#     (0): IdentityLayer()
#     (1): TopkPooling(in_features=64, in_features2=64, method=proj6, upper_bound=False, select_by_number=False, p=Parameter containing:
#     tensor([0.0020], requires_grad=True), max_iter=None, proj=Sequential(
#       (0): Linear(in_features=64, out_features=32, bias=True)
#       (1): ReLU(inplace)
#       (2): Linear(in_features=32, out_features=1, bias=True)
#     ))
#     (2): GraphPooling(['topk', 'max', 'proj6', 'ada', 'sup', 'const', 'no', '0.002'])
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=3, bias=True)
#   )
# )
# /export/mlrg/bknyazev/projects/XAI/Model/graph_examples/models.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 1199, in inner
#     self.run()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 1113, in run
#     yielded = self.gen.send(value)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2666, in run_cell
#     self.events.trigger('post_run_cell', result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/events.py", line 88, in trigger
#     func(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('agg')

# %%
datareader = graphdata.DataReader(data_dir='/mnt/data/bknyazev/data/graph_data/COLLAB',
                            rnd_state=np.random.RandomState(127),
                            folds=1,
                            N_nodes=35,
                            use_cont_node_attr=False)
data_train = graphdata.GraphData(0,
                 datareader,
                 shuffle_nodes=False,
                 batch_size=32,
                 split='train_val')
data_test = graphdata.GraphData(0,
                 datareader,
                 shuffle_nodes=False,
                 batch_size=32,
                 split='test')
# Out:
# loading data from /mnt/data/bknyazev/data/graph_data/COLLAB/data.pkl
# 5000 681 35
# good
# degree_max 491
# node shuffling is off
# TRAIN_VAL: 500/5000
# train_val: N_nodes_min: 32
# train_val: N_nodes_max: 35
# train_val, Class 0: 			227 samples
# train_val, Class 1: 			125 samples
# train_val, Class 2: 			148 samples
# node shuffling is off
# TEST: 4500/5000
# test: N_nodes_min: 32
# test: N_nodes_max: 492
# test, Class 0: 			2373 samples
# test, Class 1: 			650 samples
# test, Class 2: 			1477 samples

# %%
index = 3
A, G, pos = draw_graph(data_test, index)
# Out:
# (35, 1) (35, 35)
# label 1

# %%
n = N_nodes = A.shape[0]
D = np.sum(A, 1, keepdims=True)  # N,1  as in  [M. Simonovsky et al., CVPR'2017]
D_onehot = np.zeros((N_nodes, 491 + 1))
D_onehot[np.arange(N_nodes), D.astype(np.int).squeeze()] = 1
print(D_onehot.shape, data_test.features_onehot[index].shape)
data = (torch.from_numpy(np.concatenate((data_test.features_onehot[index], D_onehot), axis=1)).unsqueeze(0).float().to(device).expand(2, -1, -1),
            None,
            torch.from_numpy(A).unsqueeze(0).unsqueeze(3).float().to(device).to(device).expand(2, -1, -1, -1),
            {'graph_support': torch.ones(2, n).float().to(device).to(device),
             'N_nodes': torch.zeros(2, 1).long().to(device) + n,
             'signal_attn': torch.zeros(2, n).float().to(device)})
y, output = model(data)[:2]
print(y, output[1][0].shape)
alpha = output[1][0][0, :].data.numpy()
# Out:
# (35, 492) (35, 1)
# tensor([[ 1.2335,  2.3339, -3.6476],
#         [ 1.2335,  2.3339, -3.6476]], grad_fn=<ThAddmmBackward>) torch.Size([2, 35])

# %%
nx.draw(G, pos, node_color=alpha, node_size= (alpha + 0.1) * 1000, edgecolors=np.zeros(3), cmap='Purples')
plt.show()

# %% [markdown]
# # D&D

# %%
# /export/mlrg/bknyazev/projects/XAI/Model/graph_examples/results/collab/attention_35/wsup_0.5/K3_f64_64_64_lr0.001_proj6/sup_p0.002_K3_f64_50epochs_shape_split_35nodes_lr0.001_seed127.log
model = load_model('/mnt/data/bknyazev//checkpoints/checkpoint_DD_GPU9_622565_fold0_epoch50.pth.tar', 5748, 89, 2)
# Out:
# /export/mlrg/bknyazev/projects/XAI/Model/graph_examples/models.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 1199, in inner
#     self.run()
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 1113, in run
#     yielded = self.gen.send(value)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/tornado/gen.py", line 315, in wrapper
#     yielded = next(result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2666, in run_cell
#     self.events.trigger('post_run_cell', result)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/events.py", line 88, in trigger
#     func(*args, **kwargs)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/export/mlrg/bknyazev/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('agg')
# [array([3]), array([3]), array([3])] concat 300 [32]
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 267]) tensor([0.5671, 0.5945, 0.5651, 0.5932, 0.5611, 0.5540, 0.5746, 0.5625, 0.5783,
#         0.5902, 0.5905, 0.5724, 0.5538, 0.5935, 0.5782, 0.5822, 0.5799, 0.5635,
#         0.5610, 0.5728, 0.5944, 0.5702, 0.5664, 0.5506, 0.5523, 0.5883, 0.5909,
#         0.6036, 0.5684, 0.5624, 0.5717, 0.5632, 0.5705, 0.5614, 0.5892, 0.5818,
#         0.5856, 0.5923, 0.5968, 0.5674, 0.5938, 0.5752, 0.5588, 0.5823, 0.5453,
#         0.5796, 0.5763, 0.5782, 0.5918, 0.5556, 0.5834, 0.5601, 0.5980, 0.5718,
#         0.5755, 0.5415, 0.5699, 0.5847, 0.5836, 0.6141, 0.5749, 0.5543, 0.6016,
#         0.5759], grad_fn=<NormBackward1>)
# 0 0 ['no', '0.01']
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 192]) tensor([0.5742, 0.5793, 0.5827, 0.5645, 0.5934, 0.5804, 0.5891, 0.5982, 0.5285,
#         0.5843, 0.5728, 0.6097, 0.6042, 0.5500, 0.5408, 0.5791, 0.5858, 0.5431,
#         0.6081, 0.5666, 0.5839, 0.5631, 0.5997, 0.5800, 0.5913, 0.5927, 0.5660,
#         0.5866, 0.5752, 0.6033, 0.5767, 0.5902, 0.5638, 0.5490, 0.5881, 0.5917,
#         0.5966, 0.5088, 0.5987, 0.5515, 0.5867, 0.5353, 0.5503, 0.5643, 0.5795,
#         0.5904, 0.5807, 0.5796, 0.6027, 0.5836, 0.5705, 0.5882, 0.5628, 0.5625,
#         0.5644, 0.5883, 0.5826, 0.5738, 0.5655, 0.5805, 0.5773, 0.5949, 0.5840,
#         0.5687], grad_fn=<NormBackward1>)
# 1 1 ['no', '0.01']
# p= Parameter containing:
# tensor([0.0100], requires_grad=True)
# WARNING: implement bilinear!!!
# ChebyshevLayer torch.Size([64, 192]) tensor([0.5876, 0.5956, 0.5764, 0.5864, 0.5687, 0.5418, 0.5714, 0.5597, 0.6020,
#         0.5695, 0.5611, 0.5694, 0.5746, 0.6020, 0.5896, 0.5782, 0.5790, 0.6007,
#         0.5716, 0.5812, 0.5769, 0.5598, 0.6016, 0.5957, 0.5646, 0.6021, 0.5765,
#         0.5585, 0.5652, 0.5654, 0.5804, 0.5669, 0.5729, 0.5987, 0.5839, 0.5539,
#         0.5995, 0.5795, 0.6104, 0.5624, 0.5990, 0.5502, 0.5281, 0.5656, 0.5608,
#         0.5914, 0.5515, 0.5643, 0.5902, 0.5832, 0.5814, 0.5790, 0.5615, 0.5716,
#         0.6001, 0.5538, 0.5904, 0.5622, 0.5958, 0.5515, 0.5868, 0.5921, 0.5866,
#         0.5801], grad_fn=<NormBackward1>)
# ChebNet(
#   (cheb_layers): ModuleList(
#     (0): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=89, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=267, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#   )
#   (pooling_layers): ModuleList(
#     (0): IdentityLayer()
#     (1): TopkPooling(in_features=64, in_features2=64, method=proj6, upper_bound=False, select_by_number=False, p=Parameter containing:
#     tensor([0.0100], requires_grad=True), max_iter=None, proj=Sequential(
#       (0): Linear(in_features=64, out_features=32, bias=True)
#       (1): ReLU(inplace)
#       (2): Linear(in_features=32, out_features=1, bias=True)
#     ))
#     (2): GraphPooling(['topk', 'max', 'proj6', 'ada', 'sup', 'const', 'no', '0.01'])
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# model capacity: 44100
# ChebNet(
#   (cheb_layers): ModuleList(
#     (0): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=89, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=267, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): ChebyshevLayer(GCN=False, aggregation=mean, activation=None, in_features=64, out_features=64, n_hidden=0, K=[3], N_adjacencies=1(concat))
#       Sequential(
#         (0): Linear(in_features=192, out_features=64, bias=True)
#         (1): IdentityLayer()
#       )
#       (1): ReLU(inplace)
#     )
#   )
#   (pooling_layers): ModuleList(
#     (0): IdentityLayer()
#     (1): TopkPooling(in_features=64, in_features2=64, method=proj6, upper_bound=False, select_by_number=False, p=Parameter containing:
#     tensor([0.0100], requires_grad=True), max_iter=None, proj=Sequential(
#       (0): Linear(in_features=64, out_features=32, bias=True)
#       (1): ReLU(inplace)
#       (2): Linear(in_features=32, out_features=1, bias=True)
#     ))
#     (2): GraphPooling(['topk', 'max', 'proj6', 'ada', 'sup', 'const', 'no', '0.01'])
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.1)
#     (1): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
datareader = graphdata.DataReader(data_dir='/mnt/data/bknyazev/data/graph_data/DD',
                            rnd_state=np.random.RandomState(726),
                            folds=1,
                            N_nodes=300,
                            use_cont_node_attr=False)
data_train = graphdata.GraphData(0,
                 datareader,
                 shuffle_nodes=False,
                 batch_size=32,
                 split='train_val')
data_test = graphdata.GraphData(0,
                 datareader,
                 shuffle_nodes=False,
                 batch_size=32,
                 split='test')
# Out:
# loading data from /mnt/data/bknyazev/data/graph_data/DD/data.pkl
# 1178 740 300
# good
# degree_max 19
# node shuffling is off
# TRAIN_VAL: 500/1178
# train_val: N_nodes_min: 30
# train_val: N_nodes_max: 300
# train_val, Class 0: 			215 samples
# train_val, Class 1: 			285 samples
# node shuffling is off
# TEST: 678/1178
# test: N_nodes_min: 30
# test: N_nodes_max: 5748
# test, Class 0: 			476 samples
# test, Class 1: 			202 samples

# %%
index = 0
A, G, pos = draw_graph(data_test, index)
# Out:
# (182, 89) (182, 182)
# label 1

# %%
n = A.shape[0]
data = (torch.from_numpy(data_test.features_onehot[index]).unsqueeze(0).float().to(device).expand(2, -1, -1),
            None,
            torch.from_numpy(A).unsqueeze(0).unsqueeze(3).float().to(device).to(device).expand(2, -1, -1, -1),
            {'graph_support': torch.ones(2, n).float().to(device).to(device),
             'N_nodes': torch.zeros(2, 1).long().to(device) + n,
             'signal_attn': torch.zeros(2, n).float().to(device)})
y, output = model(data)[:2]
print(y, output[1][0].shape)
alpha = output[1][0][0, :].data.numpy()
# Out:
# tensor([[-0.1876,  0.3212],
#         [-0.1876,  0.3212]], grad_fn=<ThAddmmBackward>) torch.Size([2, 182])

# %%
nx.draw(G, pos, node_color=alpha, node_size=(alpha + 0.1) * 1000, edgecolors=np.zeros(3), cmap='Purples')
plt.show()

# %% [markdown]
# ## Show correctly and incorrectly classified samples
